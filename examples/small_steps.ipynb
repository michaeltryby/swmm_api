# %%
from swmm_api.input_file.sections import FilesSection
from swmm_api.input_file.section_labels import FILES
from swmm_api import SwmmInput

inp = SwmmInput()
inp['FILES'] = {'USE HOTSTART': 'xxx.HSF'}
inp[FILES] = FilesSection({'USE HOTSTART': 'xxx.HSF'})
# inp[FILES]['USE HOTSTART'] = 'xxx.HSF'
print(inp.to_string())
# Out:
# ;;____________________________________________________________________________________________________
# [FILES]
# USE HOTSTART  xxx.HSF

# %%
inp = SwmmInput.read_file('epaswmm5_apps_manual/Example5-EMC.inp')
# inp.force_convert_all()
inp.copy()
# Out:
# {'TITLE': 'Example 5\nRunoff Quality\nEMC Washoff', 'OPTIONS': {'FLOW_UNITS': 'CFS', 'INFILTRATION': 'HORTON', 'FLOW_ROUTING': 'DYNWAVE', 'START_DATE': datetime.date(2007, 1, 1), 'START_TIME': datetime.time(0, 0), 'REPORT_START_DATE': datetime.date(2007, 1, 1), 'REPORT_START_TIME': datetime.time(0, 0), 'END_DATE': datetime.date(2007, 1, 1), 'END_TIME': datetime.time(12, 0), 'SWEEP_START': '01/01', 'SWEEP_END': '12/31', 'DRY_DAYS': 5, 'REPORT_STEP': datetime.time(0, 1), 'WET_STEP': datetime.time(0, 1), 'DRY_STEP': datetime.time(1, 0), 'ROUTING_STEP': '0:00:15', 'ALLOW_PONDING': False, 'INERTIAL_DAMPING': 'PARTIAL', 'VARIABLE_STEP': 0.75, 'LENGTHENING_STEP': 0, 'MIN_SURFAREA': 0, 'NORMAL_FLOW_LIMITED': 'SLOPE', 'SKIP_STEADY_STATE': False, 'FORCE_MAIN_EQUATION': 'H-W', 'LINK_OFFSETS': 'DEPTH', 'MIN_SLOPE': 0}, 'EVAPORATION': {'CONSTANT': 0.0}, 'RAINGAGES': {'RainGage': RainGage(Name="RainGage", Format="INTENSITY", Interval="0:05", SCF=1.0, Source="TIMESERIES", Timeseries="0.1-in", Filename=NaN, Station=NaN, Units=NaN)}, 'SUBCATCHMENTS': {'S1': SubCatchment(Name="S1", RainGage="RainGage", Outlet="J1", Area=4.55, Imperv=56.8, Width=1587.0, Slope=2.0, CurbLen=1680.0, SnowPack=NaN), 'S2': SubCatchment(Name="S2", RainGage="RainGage", Outlet="J2", Area=4.74, Imperv=63.0, Width=1653.0, Slope=2.0, CurbLen=1680.0, SnowPack=NaN), 'S3': SubCatchment(Name="S3", RainGage="RainGage", Outlet="J3", Area=3.74, Imperv=39.5, Width=1456.0, Slope=3.1, CurbLen=930.0, SnowPack=NaN), 'S4': SubCatchment(Name="S4", RainGage="RainGage", Outlet="J7", Area=6.79, Imperv=49.9, Width=2331.0, Slope=3.1, CurbLen=2250.0, SnowPack=NaN), 'S5': SubCatchment(Name="S5", RainGage="RainGage", Outlet="J10", Area=4.79, Imperv=87.7, Width=1670.0, Slope=2.0, CurbLen=2480.0, SnowPack=NaN), 'S6': SubCatchment(Name="S6", RainGage="RainGage", Outlet="J11", Area=1.98, Imperv=95.0, Width=690.0, Slope=2.0, CurbLen=1100.0, SnowPack=NaN), 'S7': SubCatchment(Name="S7", RainGage="RainGage", Outlet="J10", Area=2.33, Imperv=0.0, Width=907.0, Slope=3.1, CurbLen=565.0, SnowPack=NaN)}, 'SUBAREAS': {'S1': SubArea(Subcatch="S1", N_Imperv=0.015, N_Perv=0.24, S_Imperv=0.06, S_Perv=0.3, PctZero=25.0, RouteTo="OUTLET", PctRouted=100.0), 'S2': SubArea(Subcatch="S2", N_Imperv=0.015, N_Perv=0.24, S_Imperv=0.06, S_Perv=0.3, PctZero=25.0, RouteTo="OUTLET", PctRouted=100.0), 'S3': SubArea(Subcatch="S3", N_Imperv=0.015, N_Perv=0.24, S_Imperv=0.06, S_Perv=0.3, PctZero=25.0, RouteTo="OUTLET", PctRouted=100.0), 'S4': SubArea(Subcatch="S4", N_Imperv=0.015, N_Perv=0.24, S_Imperv=0.06, S_Perv=0.3, PctZero=25.0, RouteTo="OUTLET", PctRouted=100.0), 'S5': SubArea(Subcatch="S5", N_Imperv=0.015, N_Perv=0.24, S_Imperv=0.06, S_Perv=0.3, PctZero=25.0, RouteTo="OUTLET", PctRouted=100.0), 'S6': SubArea(Subcatch="S6", N_Imperv=0.015, N_Perv=0.24, S_Imperv=0.06, S_Perv=0.3, PctZero=25.0, RouteTo="OUTLET", PctRouted=100.0), 'S7': SubArea(Subcatch="S7", N_Imperv=0.015, N_Perv=0.24, S_Imperv=0.06, S_Perv=0.3, PctZero=25.0, RouteTo="OUTLET", PctRouted=100.0)}, 'INFILTRATION': {'S1': InfiltrationHorton(Subcatch="S1", MaxRate=4.5, MinRate=0.2, Decay=6.5, DryTime=7.0, MaxInf=0.0, kind=NaN), 'S2': InfiltrationHorton(Subcatch="S2", MaxRate=4.5, MinRate=0.2, Decay=6.5, DryTime=7.0, MaxInf=0.0, kind=NaN), 'S3': InfiltrationHorton(Subcatch="S3", MaxRate=4.5, MinRate=0.2, Decay=6.5, DryTime=7.0, MaxInf=0.0, kind=NaN), 'S4': InfiltrationHorton(Subcatch="S4", MaxRate=4.5, MinRate=0.2, Decay=6.5, DryTime=7.0, MaxInf=0.0, kind=NaN), 'S5': InfiltrationHorton(Subcatch="S5", MaxRate=4.5, MinRate=0.2, Decay=6.5, DryTime=7.0, MaxInf=0.0, kind=NaN), 'S6': InfiltrationHorton(Subcatch="S6", MaxRate=4.5, MinRate=0.2, Decay=6.5, DryTime=7.0, MaxInf=0.0, kind=NaN), 'S7': InfiltrationHorton(Subcatch="S7", MaxRate=4.5, MinRate=0.2, Decay=6.5, DryTime=7.0, MaxInf=0.0, kind=NaN)}, 'JUNCTIONS': {'J1': Junction(Name="J1", Elevation=4973.0, MaxDepth=0.0, InitDepth=0.0, SurDepth=0.0, Aponded=0.0), 'J2': Junction(Name="J2", Elevation=4969.0, MaxDepth=0.0, I ...
