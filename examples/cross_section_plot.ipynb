# %%
# %load_ext autoreload
# %autoreload 2

# %%
from swmm_api.input_file.macros import to_cross_section_maker
from swmm_api.input_file.sections import CrossSection

# %%
link_label = 'Z'
c = to_cross_section_maker(CrossSection(link_label, CrossSection.SHAPES.VERT_ELLIPSE, height=4, parameter_2=3))
fig = c.profile_figure()
print(f'{c.area_v=:0.2f}')
# Out:
# c.area_v=9.35

# %%
link_label = 'A'
c = to_cross_section_maker(CrossSection(link_label, CrossSection.SHAPES.EGG, height=4))
fig = c.profile_figure()
print(f'{c.area_v=:0.2f}')
# Out:
# c.area_v=8.17

# %%
link_label = 'A2'
c = to_cross_section_maker(CrossSection(link_label, CrossSection.SHAPES.CIRCULAR, height=2))
fig = c.profile_figure()
print(f'{c.area_v=:0.2f}')
# Out:
# c.area_v=3.14

# %%
link_label = 'B'
c = to_cross_section_maker(CrossSection(link_label, CrossSection.SHAPES.RECT_ROUND, height=2, parameter_2=1, parameter_3=2))
fig = c.profile_figure()
print(f'{c.area_v=:0.4f} m²')
# Out:
# c.area_v=1.9790 m²

# %%
link_label = 'C'
c = to_cross_section_maker(CrossSection(link_label, CrossSection.SHAPES.RECT_TRIANGULAR, height=2, parameter_2=1, parameter_3=.2))
fig = c.profile_figure()
print(f'{c.area_v=:0.4f} m²')
# Out:
# c.area_v=1.9000 m²

# %%
link_label = 'D'
c = to_cross_section_maker(CrossSection(link_label, CrossSection.SHAPES.RECT_CLOSED, height=2, parameter_2=1))
fig = c.profile_figure()
print(f'{c.area_v=:0.4f} m²')
# Out:
# c.area_v=2.0000 m²

# %%
link_label = 'E'
c = to_cross_section_maker(CrossSection(link_label, CrossSection.SHAPES.TRIANGULAR, height=2, parameter_2=1))
fig = c.profile_figure()
print(f'{c.area_v=:0.4f} m²')
# Out:
# c.area_v=1.0000 m²

# %%
link_label = 'F'
c = to_cross_section_maker(CrossSection(link_label, CrossSection.SHAPES.PARABOLIC, height=2, parameter_2=1))
fig = c.profile_figure()
print(f'{c.area_v=:0.4f} m²')
# Out:
# c.area_v=1.3333 m²

# %%
link_label = 'F'
c = to_cross_section_maker(CrossSection(link_label, CrossSection.SHAPES.POWER, height=2, parameter_2=1, parameter_3=4))
fig = c.profile_figure()
print(f'{c.area_v=:0.4f} m²')
# Out:
# c.area_v=1.6000 m²

# %%
link_label = 'F2'
c = to_cross_section_maker(CrossSection(link_label, CrossSection.SHAPES.POWER, height=2, parameter_2=1, parameter_3=1))
fig = c.profile_figure()
print(f'{c.area_v=:0.4f} m²')
# Out:
# c.area_v=1.0000 m²
